# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Cardiotocographic.csv')
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# ###   	Statistical Summary

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# min      -0.001353    -0.005348   -63.000000    -6.600000   -91.000000
# 25%       0.000000     0.000000    32.000000     0.700000     0.000000
# 50%       0.000000     0.000000    49.000000     1.200000     0.000000
# 75%       0.000000     0.000000    61.000000     1.700000    11.000000
# max       0.002706     0.010695   162.000000    13.800000   182.000000
#
#               MLTV        Width     Tendency          NSP
# count  2105.000000  2105.000000  2105.000000  2105.000000
# mean      8.284887    70.429260     0.316371     1.304507
# std       7.772858    42.931822     0.645622     0.644619
# min     -50.700000  -174.000000    -3.000000    -1.025988
# 25%       4.600000    37.000000     0.000000     1.000000
# 50%       7.400000    67.000000     0.000000     1.000000
# 75%      10.900000   100.000000     1.000000     1.000000
# max     101.400000   357.000000     3.000000     5.000000

# %%
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data.shape
# Out:
# (2126, 14)

# %%
data[data.duplicated(keep=False)]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1113  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1457  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1113   39.0       0.0  1.0
# 1115   39.0       0.0  1.0
# 1457   35.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
data=data.drop_duplicates()

# %%
data.reset_index()
# Out:
#       index          LB        AC        FM        UC        DL   DS   DP  \
# 0         0  120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 1         1  132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0
# 2         2  133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0
# 3         3  134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0
# 4         4  131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0
# ...     ...         ...       ...       ...       ...       ...  ...  ...
# 2119   2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0
# 2120   2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0
# 2121   2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0
# 2122   2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0
# 2123   2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0
#
#       ASTV  MSTV       ALTV  MLTV  Width  Tendency       NSP
# 0     73.0   0.5  43.000000   2.4   64.0  0.999926  2.000000
# 1     17.0   2.1   0.000000  10.4  130.0  0.000000  1.000000
# 2     16.0   2.1   0.000000  13.4  130.0  0.000000  1.000000
# 3     16.0   2.4   0.000000  23.0  117.0  1.000000  1.000000
# 4     16.0   2.4   0.000000  19.9  117.0  1.000000  1.000000
# ...    ...   ...        ...   ...    ...       ...       ...
# 2119  79.0   0.2  25.000000   7.2   40.0  0.000000  2.000000
# 2120  78.0   0.4  22.000000   7.1   66.0  1.000000  2.000000
# 2121  79.0   0.4  20.000000   6.1   67.0  1.000000  1.990464
# 2122  78.0   0.4  27.000000   7.0   66.0  1.000000  2.000000
# 2123  74.0   0.4  35.857183   5.0   42.0  0.000000  1.000000
#
# [2124 rows x 15 columns]

# %%
colours = ['orange', 'yellow']
sns.heatmap(data.isnull(),cmap=colours)
# Out:
# <Axes: >

# %% [markdown]
# ### Data Visualization

# %%
box=plt.boxplot(data)

# %%
#box=data.DL.plot(kind='box')
box=plt.boxplot(data['DL'])

# %%
for i,j in box.items():
  print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x0000021F64329730>, <matplotlib.lines.Line2D object at 0x0000021F64329A00>]
# caps [<matplotlib.lines.Line2D object at 0x0000021F64329CD0>, <matplotlib.lines.Line2D object at 0x0000021F6432A000>]
# boxes [<matplotlib.lines.Line2D object at 0x0000021F64329430>]
# medians [<matplotlib.lines.Line2D object at 0x0000021F6432A330>]
# fliers [<matplotlib.lines.Line2D object at 0x0000021F6432A4B0>]
# means []

# %%
out=[]
for item in box["fliers"]:
    out.append(item.get_ydata())

out
# Out:
# [array([-0.01538462, -0.01538462, -0.01538462, -0.01539347, -0.01538462,
#         -0.01538462,  0.00944386,  0.00841515,  0.00834028,  0.01215805,
#          0.01000834,  0.01416431,  0.00963698,  0.00849858,  0.00829875,
#          0.01154401,  0.01538462,  0.03076923,  0.03062062,  0.03076923,
#          0.01385042,  0.01062802,  0.01362398,  0.01165803,  0.00933489,
#          0.01076716,  0.03076923,  0.01      ,  0.00920245,  0.00887574,
#          0.00876095,  0.00831601,  0.01089325,  0.01231527,  0.01144165,
#          0.00847458,  0.00921659,  0.0106383 ,  0.00824176,  0.00877193,
#          0.00944206,  0.01144984,  0.01415094,  0.01474202,  0.00824742,
#          0.0105042 ,  0.01259446,  0.0089251 ,  0.00862952,  0.00917431,
#          0.00896861,  0.00847458,  0.0087146 ,  0.00843882,  0.01224847,
#          0.01237345,  0.01263158,  0.01119403,  0.01352657,  0.00853242,
#          0.00829016,  0.00926843,  0.01034929,  0.00935829,  0.01227679,
#          0.01306413,  0.01179941,  0.01057579,  0.00865385,  0.0096238 ,
#          0.00834202,  0.01016636,  0.00890869,  0.00940681,  0.0094697 ,
#          0.00871249,  0.01468189,  0.01042654,  0.01131687,  0.01177856,
#          0.01029748,  0.00944384,  0.00825472,  0.00845411,  0.00915565,
#          0.00846433,  0.00880503,  0.01046338,  0.01360544,  0.0106383 ,
#          0.01303538,  0.01181102,  0.01183682,  0.01437372,  0.01340033,
#          0.01313869,  0.01045752,  0.00928793,  0.00847458,  0.00870827,
#          0.00840336,  0.00894877,  0.00870511,  0.00928793,  0.00904393,
#          0.00943396,  0.00956938,  0.01129235,  0.00892857,  0.00838323,
#          0.01089588,  0.01091703,  0.01268116,  0.01345362,  0.01008827,
#          0.00909091,  0.00829493,  0.00826446,  0.00916031,  0.00883392,
#          0.00977778,  0.00943396,  0.00986842,  0.01004016,  0.00869565])]

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>, <Axes: title={'center': 'UC'}>],
#        [<Axes: title={'center': 'DL'}>, <Axes: title={'center': 'DS'}>,
#         <Axes: title={'center': 'DP'}>, <Axes: title={'center': 'ASTV'}>],
#        [<Axes: title={'center': 'MSTV'}>,
#         <Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>,
#         <Axes: title={'center': 'Width'}>],
#        [<Axes: title={'center': 'Tendency'}>,
#         <Axes: title={'center': 'NSP'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.violinplot(data['MSTV'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x21f6422b4a0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x21f641f51f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x21f642297c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x21f641999a0>}

# %%
sns.stripplot(y='Width',data=data,jitter=True)
# Out:
# <Axes: ylabel='Width'>

# %% [markdown]
# ###  correlation between the variables

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.064452  0.018810 -0.167012 -0.126981 -0.005439
# AC       -0.064452  1.000000  0.009407  0.071700 -0.093641 -0.033632
# FM        0.018810  0.009407  1.000000 -0.053386  0.009641  0.029899
# UC       -0.167012  0.071700 -0.053386  1.000000  0.189737 -0.006957
# DL       -0.126981 -0.093641  0.009641  0.189737  1.000000  0.058625
# DS       -0.005439 -0.033632  0.029899 -0.006957  0.058625  1.000000
# DP       -0.047726 -0.084644  0.121259  0.070504  0.145338  0.004282
# ASTV      0.242435 -0.231725 -0.032838 -0.182379 -0.069907  0.008441
# MSTV     -0.170134  0.134423  0.017061  0.189685  0.410216  0.016165
# ALTV      0.210955 -0.271554 -0.012005 -0.227881 -0.187275 -0.004406
# MLTV     -0.003225 -0.106308 -0.006157 -0.048862 -0.165494  0.034366
# Width    -0.118375  0.238422  0.097133  0.106787  0.409793  0.040831
# Tendency  0.237112  0.032399 -0.018410 -0.067098 -0.023838 -0.015408
# NSP       0.132008 -0.317113  0.073997 -0.185953  0.025179  0.065399
#
#                 DP      ASTV      MSTV      ALTV      MLTV     Width  \
# LB       -0.047726  0.242435 -0.170134  0.210955 -0.003225 -0.118375
# AC       -0.084644 -0.231725  0.134423 -0.271554 -0.106308  0.238422
# FM        0.121259 -0.032838  0.017061 -0.012005 -0.006157  0.097133
# UC        0.070504 -0.182379  0.189685 -0.227881 -0.048862  0.106787
# DL        0.145338 -0.069907  0.410216 -0.187275 -0.165494  0.409793
# DS        0.004282  0.008441  0.016165 -0.004406  0.034366  0.040831
# DP        1.000000  0.038076  0.119911 -0.077865 -0.113993  0.175240
# ASTV      0.038076  1.000000 -0.293820  0.357310 -0.219922 -0.208439
# MSTV      0.119911 -0.293820  1.000000 -0.291979  0.028807  0.435563
# ALTV     -0.077865  0.357310 -0.291979  1.000000 -0.107475 -0.346960
# MLTV     -0.113993 -0.219922  0.028807 -0.107475  1.000000  0.059031
# Width     0.175240 -0.208439  0.435563 -0.346960  0.059031  1.000000
# Tendency -0.130510 -0.011367 -0.036849  0.036552  0.116672  0.081025
# NSP       0.294416  0.422515 -0.095143  0.365708 -0.113445 -0.067799
#
#           Tendency       NSP
# LB        0.237112  0.132008
# AC        0.032399 -0.317113
# FM       -0.018410  0.073997
# UC       -0.067098 -0.185953
# DL       -0.023838  0.025179
# DS       -0.015408  0.065399
# DP       -0.130510  0.294416
# ASTV     -0.011367  0.422515
# MSTV     -0.036849 -0.095143
# ALTV      0.036552  0.365708
# MLTV      0.116672 -0.113445
# Width     0.081025 -0.067799
# Tendency  1.000000 -0.106481
# NSP      -0.106481  1.000000

# %% [markdown]
# ###  Filling null values

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean_lb=data['LB'].mean()
print(mean_lb)
data['LB']=data['LB'].fillna(mean_lb)
# Out:
# 133.3420230800519

# %%
mean_ac=data['AC'].mean()
print(mean_ac)
data['AC']=data['AC'].fillna(mean_ac)
# Out:
# 0.0032197961979291345

# %%
mean_ds=data['DS'].mean()
print(mean_ds)
data['DS']=data['DS'].fillna(mean_ds)
# Out:
# 2.511369605097549e-06

# %%
mean_dp=data['DP'].mean()
print(mean_dp)
data['DP']=data['DP'].fillna(mean_dp)
# Out:
# 0.00017531778446317666

# %%
mean_mltv=data['MLTV'].mean()
print(mean_mltv)
data['MLTV']=data['MLTV'].fillna(mean_mltv)
# Out:
# 8.28054590298053

# %%
mean_width=data['Width'].mean()
print(mean_width)
data['Width']=data['Width'].fillna(mean_width)
# Out:
# 70.46105246796047

# %%
mean_tendency=data['Tendency'].mean()
print(mean_tendency)
data['Tendency']=data['Tendency'].fillna(mean_tendency)
# Out:
# 0.31667228014592036

# %%
mean_nsp=data['NSP'].mean()
print(mean_nsp)
data['NSP']=data['NSP'].fillna(mean_nsp)
# Out:
# 1.304796768239931

# %% [markdown]
# ###  Outliers  Treatment

# %%
plt.boxplot(x='DL',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65b62630>,
#   <matplotlib.lines.Line2D at 0x21f65b60530>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65b60920>,
#   <matplotlib.lines.Line2D at 0x21f65b78aa0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65b60ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65b7bdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65b7a600>],
#  'means': []}

# %%
# Detect and treat outliers (if necessary)
# Using IQR method (adjust thresholds as needed)
Q1 = data['DL'].quantile(0.25)
Q3 = data['DL'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['DL'] >= lower_bound) & (data['DL'] <= upper_bound)]

# %%
plt.boxplot(x='DL',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f658a67b0>,
#   <matplotlib.lines.Line2D at 0x21f658a6ab0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f658a6de0>,
#   <matplotlib.lines.Line2D at 0x21f658a7110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f658a64b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f658a72f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f658a7530>],
#  'means': []}

# %%
plt.boxplot(x='ALTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f658fbad0>,
#   <matplotlib.lines.Line2D at 0x21f658fbdd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f6592c0e0>,
#   <matplotlib.lines.Line2D at 0x21f6592c3b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f658fb830>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6592c500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6592c830>],
#  'means': []}

# %%
Q1 = data['ALTV'].quantile(0.25)
Q3 = data['ALTV'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['ALTV'] >= lower_bound) & (data['ALTV'] <= upper_bound)]

# %%
plt.boxplot(x='ALTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f6597a1b0>,
#   <matplotlib.lines.Line2D at 0x21f6597a4b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f6597a7b0>,
#   <matplotlib.lines.Line2D at 0x21f6597a960>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65979ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6597ac30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6597af00>],
#  'means': []}

# %%
plt.boxplot(x='LB',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65e84710>,
#   <matplotlib.lines.Line2D at 0x21f65e84a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65e84d10>,
#   <matplotlib.lines.Line2D at 0x21f65e85040>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65e84470>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65e851f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65e85430>],
#  'means': []}

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
Q1 = data['LB'].quantile(0.25)
Q3 = data['LB'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['LB'] >= lower_bound) & (data['LB'] <= upper_bound)]

# %%
plt.boxplot(x='LB',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65ebbfb0>,
#   <matplotlib.lines.Line2D at 0x21f65ef02c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65ef05c0>,
#   <matplotlib.lines.Line2D at 0x21f65ef08f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65ebbd40>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65ef0ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65ef0da0>],
#  'means': []}

# %%
plt.boxplot(x='AC',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65d0e180>,
#   <matplotlib.lines.Line2D at 0x21f65d0e480>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65d0e720>,
#   <matplotlib.lines.Line2D at 0x21f65d0e9f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65d0df10>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65d0eba0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65d0ee10>],
#  'means': []}

# %%
Q1 = data['AC'].quantile(0.25)
Q3 = data['AC'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['AC'] >= lower_bound) & (data['AC'] <= upper_bound)]

# %%
plt.boxplot(x='AC',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65d84590>,
#   <matplotlib.lines.Line2D at 0x21f65d84890>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65d84bc0>,
#   <matplotlib.lines.Line2D at 0x21f65d84e90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65d842c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65d84fe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65d85220>],
#  'means': []}

# %%
plt.boxplot(x='FM',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65df8410>,
#   <matplotlib.lines.Line2D at 0x21f65df86e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65df89b0>,
#   <matplotlib.lines.Line2D at 0x21f65df8ce0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65df81d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65d4c290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65df8e60>],
#  'means': []}

# %%
Q1 = data['FM'].quantile(0.25)
Q3 = data['FM'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['FM'] >= lower_bound) & (data['FM'] <= upper_bound)]

# %%
plt.boxplot(x='FM',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65f7b2c0>,
#   <matplotlib.lines.Line2D at 0x21f65f7b5c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65f7b890>,
#   <matplotlib.lines.Line2D at 0x21f65f7bb30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65f7afc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65f7bd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65fa0050>],
#  'means': []}

# %%
plt.boxplot(x='UC',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65ff0170>,
#   <matplotlib.lines.Line2D at 0x21f65ff0410>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65ff0680>,
#   <matplotlib.lines.Line2D at 0x21f65ff0950>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65fbbe90>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65ff0ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65ff0dd0>],
#  'means': []}

# %%
Q1 = data['UC'].quantile(0.25)
Q3 = data['UC'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['UC'] >= lower_bound) & (data['UC'] <= upper_bound)]

# %%
plt.boxplot(x='UC',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f67049370>,
#   <matplotlib.lines.Line2D at 0x21f67049670>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f67049970>,
#   <matplotlib.lines.Line2D at 0x21f67049c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f670490d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f67049df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6704a0c0>],
#  'means': []}

# %%
plt.boxplot(x='DS',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f670974a0>,
#   <matplotlib.lines.Line2D at 0x21f67097710>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f670979b0>,
#   <matplotlib.lines.Line2D at 0x21f67097c50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f67097200>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f67097e30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f670c8110>],
#  'means': []}

# %%
Q1 = data['DS'].quantile(0.25)
Q3 = data['DS'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['DS'] >= lower_bound) & (data['DS'] <= upper_bound)]

# %%
plt.boxplot(x='DS',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f670fdfa0>,
#   <matplotlib.lines.Line2D at 0x21f670fe2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f670fe570>,
#   <matplotlib.lines.Line2D at 0x21f670fe8a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f670fdd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6704a570>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f670fccb0>],
#  'means': []}

# %%
plt.boxplot(x='DP',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f672b3050>,
#   <matplotlib.lines.Line2D at 0x21f672b32f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f672b3560>,
#   <matplotlib.lines.Line2D at 0x21f672b3740>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f672b28d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f672b39b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f672b3cb0>],
#  'means': []}

# %%
Q1 = data['DP'].quantile(0.25)
Q3 = data['DP'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['DP'] >= lower_bound) & (data['DP'] <= upper_bound)]

# %%
plt.boxplot(x='DP',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f6732cbf0>,
#   <matplotlib.lines.Line2D at 0x21f6732ce60>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f6732d190>,
#   <matplotlib.lines.Line2D at 0x21f6732d490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f6732c950>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6732d640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6732d940>],
#  'means': []}

# %%
plt.boxplot(x='ASTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f67379df0>,
#   <matplotlib.lines.Line2D at 0x21f6737a0f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f6737a3c0>,
#   <matplotlib.lines.Line2D at 0x21f6737a5a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f67379c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6737a840>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6737ab10>],
#  'means': []}

# %%
Q1 = data['ASTV'].quantile(0.25)
Q3 = data['ASTV'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['ASTV'] >= lower_bound) & (data['ASTV'] <= upper_bound)]

# %%
plt.boxplot(x='ASTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f6717dfa0>,
#   <matplotlib.lines.Line2D at 0x21f6717e2a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f6717e5a0>,
#   <matplotlib.lines.Line2D at 0x21f6717e870>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f6717dd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6717ea20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6717ecf0>],
#  'means': []}

# %%
plt.boxplot(x='MSTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f67218c50>,
#   <matplotlib.lines.Line2D at 0x21f67218e90>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f67219130>,
#   <matplotlib.lines.Line2D at 0x21f67219400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f672189e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f67219580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f67219880>],
#  'means': []}

# %%
Q1 = data['MSTV'].quantile(0.25)
Q3 = data['MSTV'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['MSTV'] >= lower_bound) & (data['MSTV'] <= upper_bound)]

# %%
plt.boxplot(x='MSTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f674ea4e0>,
#   <matplotlib.lines.Line2D at 0x21f674ea7b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f674eaa80>,
#   <matplotlib.lines.Line2D at 0x21f674ead80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f674ea210>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f674eaf60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f674eb230>],
#  'means': []}

# %%
plt.boxplot(x='MLTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f67547590>,
#   <matplotlib.lines.Line2D at 0x21f67547860>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f67547b00>,
#   <matplotlib.lines.Line2D at 0x21f67547e00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f67547290>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f67547cb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f67544110>],
#  'means': []}

# %%
Q1 = data['MLTV'].quantile(0.25)
Q3 = data['MLTV'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['MLTV'] >= lower_bound) & (data['MLTV'] <= upper_bound)]

# %%
plt.boxplot(x='MLTV',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f675b8ad0>,
#   <matplotlib.lines.Line2D at 0x21f675b8da0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f675b90a0>,
#   <matplotlib.lines.Line2D at 0x21f675b9370>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f675b8800>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f675b9520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f675b97f0>],
#  'means': []}

# %%
plt.boxplot(x='Width',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f658653a0>,
#   <matplotlib.lines.Line2D at 0x21f641f6ab0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f641f4260>,
#   <matplotlib.lines.Line2D at 0x21f642c4cb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f6584f0e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f642c7ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f63fa38c0>],
#  'means': []}

# %%
Q1 = data['Width'].quantile(0.25)
Q3 = data['Width'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['Width'] >= lower_bound) & (data['Width'] <= upper_bound)]

# %%
plt.boxplot(x='Width',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f65b62f00>,
#   <matplotlib.lines.Line2D at 0x21f65e84230>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f65e86ab0>,
#   <matplotlib.lines.Line2D at 0x21f65e87410>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f65b613d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f65e86d20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f65bca960>],
#  'means': []}

# %%
plt.boxplot(x='Tendency',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f673c18e0>,
#   <matplotlib.lines.Line2D at 0x21f673c1b80>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f673c1e80>,
#   <matplotlib.lines.Line2D at 0x21f673c2120>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f673c12e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f673c22a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f673c25a0>],
#  'means': []}

# %%
Q1 = data['Tendency'].quantile(0.25)
Q3 = data['Tendency'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['Tendency'] >= lower_bound) & (data['Tendency'] <= upper_bound)]

# %%
plt.boxplot(x='Tendency',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f685d77d0>,
#   <matplotlib.lines.Line2D at 0x21f685d7a40>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f685d7cb0>,
#   <matplotlib.lines.Line2D at 0x21f685d7f80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f685d7590>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f6860c1a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f6860c3e0>],
#  'means': []}

# %%
plt.boxplot(x='NSP',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f68647140>,
#   <matplotlib.lines.Line2D at 0x21f68647410>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f68647710>,
#   <matplotlib.lines.Line2D at 0x21f686479e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f68646ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f68647bf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f68647ef0>],
#  'means': []}

# %%
Q1 = data['NSP'].quantile(0.25)
Q3 = data['NSP'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['NSP'] >= lower_bound) & (data['NSP'] <= upper_bound)]

# %%
plt.boxplot(x='NSP',data=data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f68810e30>,
#   <matplotlib.lines.Line2D at 0x21f68811100>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f688113d0>,
#   <matplotlib.lines.Line2D at 0x21f68811670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f68810c20>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f68811880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f68811ac0>],
#  'means': []}

# %%
data.describe()
# Out:
#                LB          AC          FM          UC          DL     DS  \
# count  884.000000  884.000000  884.000000  884.000000  884.000000  884.0
# mean   132.040762    0.004139    0.000603    0.004913    0.001499    0.0
# std      9.285937    0.003850    0.001349    0.002685    0.002208    0.0
# min    106.000000   -0.000122   -0.002467   -0.000101   -0.000124    0.0
# 25%    125.000000    0.000000    0.000000    0.003103    0.000000    0.0
# 50%    133.000000    0.003354    0.000000    0.005004    0.000000    0.0
# 75%    138.250000    0.006805    0.000289    0.006833    0.002765    0.0
# max    160.000000    0.015642    0.006565    0.012072    0.008197    0.0
#
#           DP        ASTV        MSTV        ALTV        MLTV       Width  \
# count  884.0  884.000000  884.000000  884.000000  884.000000  884.000000
# mean     0.0   42.409542    1.246387    3.395953    8.533525   66.616855
# std      0.0   15.030859    0.509918    6.447475    4.483267   31.547380
# min      0.0   15.000000    0.300000   -1.043619   -0.136053   12.000000
# 25%      0.0   29.000000    0.900000    0.000000    5.600000   40.000000
# 50%      0.0   41.000000    1.200000    0.000000    8.400000   60.000000
# 75%      0.0   56.000000    1.600000    4.000000   11.300000   92.000000
# max      0.0   79.000000    2.800000   30.000000   20.000000  163.000000
#
#          Tendency    NSP
# count  884.000000  884.0
# mean     0.341700    1.0
# std      0.581785    0.0
# min     -1.006614    1.0
# 25%      0.000000    1.0
# 50%      0.000000    1.0
# 75%      1.000000    1.0
# max      1.023635    1.0
